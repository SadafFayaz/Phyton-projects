# %%
import numpy as np
yoo=np.array([9,12,3,2,1,54,66,54,33])
mean_yoo=np.mean(yoo)
print("mean=",mean_yoo)
max_yoo=np.max(yoo)
print("max=",max_yoo)
min_yoo=np.min(yoo)
print("min=",min_yoo)
standaradvalue=np.std(yoo)
print("standarad value=",standaradvalue)
# Out:
# mean= 26.0
# max= 66
# min= 1
# standarad value= 24.567367696917707
