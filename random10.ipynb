# %%
import numpy
numpy.listt = [5,6,89,0,87,54,67,76,86,33]
print(numpy.list)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 3
#       1 import numpy
#       2 numpy.listt = [5,6,89,0,87,54,67,76,86,33]
# ----> 3 print(numpy.list)
#
# File ~\anaconda3\Lib\site-packages\numpy\__init__.py:414, in __getattr__(attr)
#     411     import numpy.char as char
#     412     return char.chararray
# --> 414 raise AttributeError("module {!r} has no attribute "
#     415                      "{!r}".format(__name__, attr))
#
# AttributeError: module 'numpy' has no attribute 'list'

# %%
import numpy as np
yeah = np.random.randint(1,200,10)
print(yeah)
# Out:
# [102 113 174  76   1  21  33  76  38 122]
